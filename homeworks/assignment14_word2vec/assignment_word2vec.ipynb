# %% [markdown]
# ## Бонусное задание: word2vec на PyTorch
#
# Как вы уже могли заметить, идея, лежащая в основе [word2vec](https://arxiv.org/pdf/1310.4546), достаточно общая. В данном задании вы реализуете его самостоятельно.
#
# Дисклеймер: не стоит удивляться тому, что реализация от `gensim` (или аналоги) обучается быстрее и работает точнее. Она использует множество доработок и ускорений, а также достаточно эффективный код. Ваша задача добиться промежуточных результатов за разумное время.
#
# P.s. Как ни странно, GPU в этом задании нам не потребуется.

# %% [markdown]
# __Requirements:__ if you're running locally, in the selected environment run the following command:
#
# ```pip install --upgrade nltk bokeh umap-learn```

# %%
#!pip install --upgrade nltk bokeh umap-learn
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.10/dist-packages (3.4.3)
# Collecting bokeh
#   Downloading bokeh-3.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting umap-learn
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh) (1.3.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh) (24.1)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh) (2024.9.0)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.5.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 18.8 MB/s eta 0:00:00
# Downloading bokeh-3.6.0-py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 71.0 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 4.6 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: nltk, pynndescent, bokeh, umap-learn
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 3.4.3
#     Uninstalling bokeh-3.4.3:
#       Successfully uninstalled bokeh-3.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# panel 1.4.5 requires bokeh<3.5.0,>=3.4.0, but you have bokeh 3.6.0 which is incompatible.
# Successfully installed bokeh-3.6.0 nltk-3.9.1 pynndescent-0.5.13 umap-learn-0.5.7

# %%
import itertools
import random
import string
from collections import Counter
from itertools import chain

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import umap
import math
from IPython.display import clear_output
from matplotlib import pyplot as plt
from nltk.tokenize import WordPunctTokenizer
from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR
from tqdm.auto import tqdm as tqdma

# %%
# download the data:
# !wget https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1 -O ./quora.txt -nc
# alternative download link: https://yadi.sk/i/BPQrUu1NaTduEw
# Out:
# --2024-10-29 17:23:38--  https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/p0t2dw6oqs6oxpd6zz534/quora.txt?rlkey=bjupppwua4zmd4elz8octecy9&dl=1 [following]
# --2024-10-29 17:23:39--  https://www.dropbox.com/scl/fi/p0t2dw6oqs6oxpd6zz534/quora.txt?rlkey=bjupppwua4zmd4elz8octecy9&dl=1
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc6654c32306920c979e94f5a07b.dl.dropboxusercontent.com/cd/0/inline/CdYa5cyQUZLHXtuJ7OmJXBRPpTgOjd20ZvOkI3nnA_A-BcVSD6e3d3NWRzYQqS_jC8GKVnnFa80zoIYQRFfoRLZlsumbG0qZFQcpeYYuhIUWOgwaFR2s2GheEw95ylsi26g/file?dl=1# [following]
# --2024-10-29 17:23:39--  https://uc6654c32306920c979e94f5a07b.dl.dropboxusercontent.com/cd/0/inline/CdYa5cyQUZLHXtuJ7OmJXBRPpTgOjd20ZvOkI3nnA_A-BcVSD6e3d3NWRzYQqS_jC8GKVnnFa80zoIYQRFfoRLZlsumbG0qZFQcpeYYuhIUWOgwaFR2s2GheEw95ylsi26g/file?dl=1
# Resolving uc6654c32306920c979e94f5a07b.dl.dropboxusercontent.com (uc6654c32306920c979e94f5a07b.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:6019:15::a27d:40f
# Connecting to uc6654c32306920c979e94f5a07b.dl.dropboxusercontent.com (uc6654c32306920c979e94f5a07b.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33813903 (32M) [application/binary]
# Saving to: ‘./quora.txt’
#
# ./quora.txt         100%[===================>]  32.25M  62.1MB/s    in 0.5s
#
# 2024-10-29 17:23:40 (62.1 MB/s) - ‘./quora.txt’ saved [33813903/33813903]

# %%
data = list(open("./quora.txt", encoding="utf-8"))
data[50]
# Out:
# "What TV shows or books help you read people's body language?\n"

# %% [markdown]
# Токенизация – первый шаг.
# Тексты, с которыми мы работаем, включают в себя пунктуацию, смайлики и прочие нестандартные токены, так что простой `str.split` не подойдет.
#
# Обратимся к `nltk` - библиотеку, нашла широкое применеие в области NLP.

# %%
tokenizer = WordPunctTokenizer()

print(tokenizer.tokenize(data[50]))
# Out:
# ['What', 'TV', 'shows', 'or', 'books', 'help', 'you', 'read', 'people', "'", 's', 'body', 'language', '?']

# %%
data_tok = [
    tokenizer.tokenize(
        line.translate(str.maketrans("", "", string.punctuation)).lower()
    )
    for line in data
]
data_tok = [x for x in data_tok if len(x) >= 3]

# %% [markdown]
# Несколько проверок:

# %%
assert all(
    isinstance(row, (list, tuple)) for row in data_tok
), "please convert each line into a list of tokens (strings)"
assert all(
    all(isinstance(tok, str) for tok in row) for row in data_tok
), "please convert each line into a list of tokens (strings)"
is_latin = lambda tok: all("a" <= x.lower() <= "z" for x in tok)
assert all(
    map(lambda l: not is_latin(l) or l.islower(), map(" ".join, data_tok))
), "please make sure to lowercase the data"

# %% [markdown]
# Ниже заданы константы ширины окна контекста и проведена предобработка для построения skip-gram модели.

# %%
min_count = 5
window_radius = 5

# %%
vocabulary_with_counter = Counter(chain.from_iterable(data_tok))

word_count_dict = dict()
for word, counter in vocabulary_with_counter.items():
    if counter >= min_count:
        word_count_dict[word] = counter

vocabulary = set(word_count_dict.keys())
del vocabulary_with_counter

# %%
word_to_index = {word: index for index, word in enumerate(vocabulary)}
index_to_word = {index: word for word, index in word_to_index.items()}

# %% [markdown]
# Пары `(слово, контекст)` на основе доступного датасета сгенерированы ниже.

# %%
context_pairs = []

for text in data_tok:
    for i, central_word in enumerate(text):
        context_indices = range(
            max(0, i - window_radius), min(i + window_radius, len(text))
        )
        for j in context_indices:
            if j == i:
                continue
            context_word = text[j]
            if central_word in vocabulary and context_word in vocabulary:
                context_pairs.append(
                    (word_to_index[central_word], word_to_index[context_word])
                )

print(f"Generated {len(context_pairs)} pairs of target and context words.")
# Out:
# Generated 40220313 pairs of target and context words.

# %% [markdown]
# #### Подзадача №1: subsampling
# Для того, чтобы сгладить разницу в частоте встречаемсости слов, необходимо реализовать механизм subsampling'а.
# Для этого вам необходимо реализовать функцию ниже.
#
# Вероятность **исключить** слово из обучения (на фиксированном шаге) вычисляется как
# $$
# P_\text{drop}(w_i)=1 - \sqrt{\frac{t}{f(w_i)}},
# $$
# где $f(w_i)$ – нормированная частота встречаемости слова, а $t$ – заданный порог (threshold).

# %%
def subsample_frequent_words(word_count_dict, threshold=1e-5):
    """
    Calculates the subsampling probabilities for words based on their frequencies.

    This function is used to determine the probability of keeping a word in the dataset
    when subsampling frequent words. The method used is inspired by the subsampling approach
    in Word2Vec, where each word's frequency affects its probability of being kept.

    Parameters:
    - word_count_dict (dict): A dictionary where keys are words and values are the counts of those words.
    - threshold (float, optional): A threshold parameter used to adjust the frequency of word subsampling.
                                   Defaults to 1e-5.

    Returns:
    - dict: A dictionary where keys are words and values are the probabilities of keeping each word.

    Example:
    >>> word_counts = {'the': 5000, 'is': 1000, 'apple': 50}
    >>> subsample_frequent_words(word_counts)
    {'the': 0.028, 'is': 0.223, 'apple': 1.0}
    """
    total_count = sum(word_count_dict.values())
    print(f"Total word count: {total_count}")

    keep_prob_dict = {word: 0 for word in word_count_dict.keys()}  # Placeholder

    for word, count in word_count_dict.items():
        freq = count / total_count
        if freq > threshold:
            keep_prob = math.sqrt(threshold / freq)
            keep_prob = min(1.0, keep_prob)
        else:
            keep_prob = 1.0
        keep_prob_dict[word] = keep_prob
        print(f"Word: '{word}', Count: {count}, Frequency: {freq:.6f}, Keep Probability: {keep_prob:.6f}")

    return keep_prob_dict

# %% [markdown]
# #### Подзадача №2: negative sampling
# Для более эффективного обучения необходимо не только предсказывать высокие вероятности для слов из контекста, но и предсказывать низкие для слов, не встреченных в контексте. Для этого вам необходимо вычислить вероятност использовать слово в качестве negative sample, реализовав функцию ниже.
#
# В оригинальной статье предлагается оценивать вероятность слов выступать в качестве negative sample согласно распределению $P_n(w)$
# $$
# P_n(w) = \frac{U(w)^{3/4}}{Z},
# $$
#
# где $U(w)$ распределение слов по частоте (или, как его еще называют, по униграммам), а $Z$ – нормировочная константа, чтобы общая мера была равна $1$.

# %%
def get_negative_sampling_prob(word_count_dict):
    """
    Calculates the negative sampling probabilities for words based on their frequencies.

    This function adjusts the frequency of each word raised to the power of 0.75, which is
    commonly used in algorithms like Word2Vec to moderate the influence of very frequent words.
    It then normalizes these adjusted frequencies to ensure they sum to 1, forming a probability
    distribution used for negative sampling.

    Parameters:
    - word_count_dict (dict): A dictionary where keys are words and values are the counts of those words.

    Returns:
    - dict: A dictionary where keys are words and values are the probabilities of selecting each word
            for negative sampling.

    Example:
    >>> word_counts = {'the': 5000, 'is': 1000, 'apple': 50}
    >>> get_negative_sampling_prob(word_counts)
    {'the': 0.298, 'is': 0.160, 'apple': 0.042}
    """

    # Step 1: Extract words and counts
    words = list(word_count_dict.keys())
    counts = np.array([word_count_dict[word] for word in words], dtype=np.float64)

    # Step 2: Raise counts to the power of 0.75
    adjusted_counts = counts ** 0.75

    # Step 3: Calculate the normalization constant Z
    Z = np.sum(adjusted_counts)

    # Step 4: Compute negative sampling probabilities
    negative_sampling_probs = adjusted_counts / Z

    # Step 5: Create a dictionary mapping words to their probabilities
    negative_sampling_prob_dict = {
        word: prob for word, prob in zip(words, negative_sampling_probs)
    }

    return negative_sampling_prob_dict

# %%
def subsample_frequent_words(word_count_dict, threshold=1e-5):
    """
    Calculates the subsampling probabilities for words based on their frequencies.

    Parameters:
    - word_count_dict (dict): A dictionary where keys are words and values are the counts of those words.
    - threshold (float, optional): Threshold for subsampling. Defaults to 1e-5.

    Returns:
    - dict: A dictionary with words as keys and keep probabilities as values.
    """
    total_count = sum(word_count_dict.values())
    print(f"Total word count: {total_count}")

    keep_prob_dict = {word: 0 for word in word_count_dict.keys()}  # Placeholder

    for word, count in word_count_dict.items():
        freq = count / total_count
        if freq > threshold:
            keep_prob = math.sqrt(threshold / freq)
            keep_prob = min(1.0, keep_prob)
        else:
            keep_prob = 1.0
        keep_prob_dict[word] = keep_prob
        print(f"Word: '{word}', Count: {count}, Frequency: {freq:.6f}, Keep Probability: {keep_prob:.6f}")

    return keep_prob_dict

# %% [markdown]
# Для удобства, преобразуем полученные словари в массивы (т.к. все слова все равно уже пронумерованы).

# %%
keep_prob_dict = subsample_frequent_words(word_count_dict)
assert keep_prob_dict.keys() == word_count_dict.keys()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Word: 'v5', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'crunches', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '250k', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'charm', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'meow', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'stereotyped', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'footer', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dwarfs', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'diminish', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'pumped', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'jerks', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'royals', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'synonymous', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: '1300', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'theyd', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: '224', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'innings', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'genome', Count: 29, Frequency: 0.000005, Keep Probability: 1.000000
# Word: 'restructuring', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'conceal', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'kiip', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'arthakranti', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'neurosurgeon', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'infidelity', Count: 25, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'guild', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sniff', Count: 16, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'heuer', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '1960', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'starred', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'intellectuals', Count: 20, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'sentry', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'abduction', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'constructors', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'endeavor', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'inactivity', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'evangelical', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'promiscuous', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'ronaldos', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'fajitas', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dressing', Count: 38, Frequency: 0.000006, Keep Probability: 1.000000
# Word: 'hardy', Count: 21, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'loosening', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'foreskin', Count: 25, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'murdoch', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'chlorinated', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'privatization', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'shiite', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'biriyani', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'battleships', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '﻿', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'bhp', Count: 19, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'unspoken', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'fares', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'mantras', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'hbti', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'modded', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'xerox', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'lamarcks', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'citing', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'lymphoma', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'amul', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'parlour', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'cynicism', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'wp', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'unnoticed', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'turbotax', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'watermark', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'mcgraw', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'footballers', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'fumes', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sgsits', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'fujian', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'thermometer', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'outliers', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'garments', Count: 28, Frequency: 0.000005, Keep Probability: 1.000000
# Word: 'handson', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'lace', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'approachable', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ranch', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'itwill', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sociable', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ccmt', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '100000000', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'optin', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ssri', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'bulky', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'cynical', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'द', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ो', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'त', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'म', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'न', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'एक', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'क', Count: 22, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'ज', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ह', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'urination', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'indicated', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'profiler', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'graviton', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'gamble', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'onpage', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '225', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'ldr', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'positioned', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'blond', Count: 18, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'chant', Count: 19, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'eminems', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: '±', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'rp', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '08', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'cwc', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'fabricate', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'stardust', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'bikers', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'yahoos', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'rotors', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ontology', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'gurus', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'hinged', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'multilevel', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'ciliated', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'acidbase', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'gaulle', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'varies', Count: 19, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'pat', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'axiomatic', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dung', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'countertops', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'misleading', Count: 23, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'recognizing', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'biker', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'oxymoron', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'prefixes', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'ipv4', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'ipv6', Count: 18, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'leds', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'hunts', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'subtitle', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'pushover', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'afro', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ecole', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sheriff', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'entangled', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'cdm', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'customary', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'antiques', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'coc', Count: 19, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'msis', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'crews', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'sadhguru', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'jaggi', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'vasudev', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'eyre', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'disregard', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'keynes', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'undertake', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'onetime', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'defrost', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'forensics', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sullivan', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'departed', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'stallman', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'rms', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'kettle', Count: 20, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'mcdonald', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'titin', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dashboard', Count: 27, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'costumes', Count: 25, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'meanest', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'akc', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'raksha', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'bandhan', Count: 18, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'deflect', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'northsouth', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'utopian', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'cancellation', Count: 32, Frequency: 0.000005, Keep Probability: 1.000000
# Word: 'wrestle', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mmorpg', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ix', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'fishers', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'bsms', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'individually', Count: 25, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'ergonomics', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'debitcredit', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'paramedics', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'burritos', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'paradigms', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'lockscreen', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ramaiah', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'racket', Count: 20, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'ultrabook', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nrenro', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'announcing', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dcs', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'partly', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'pdfs', Count: 20, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'crossword', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'europa', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'annex', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'olympian', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'asic', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'miner', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'defamation', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'assumption', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'claudius', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dhulagarh', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'snl', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'fico', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'funerals', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'fabulous', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'musicals', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'handloom', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'oreilly', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'vasco', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'designjet', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'calisthenics', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'observable', Count: 27, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'electromagnetism', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'baywatch', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'weightless', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'meds', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'wahhabi', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'goodness', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'jeep', Count: 24, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'arrear', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'garrett', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'shunt', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'aprons', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'orbits', Count: 24, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'comets', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'sawant', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'discretionary', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'appointing', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'stds', Count: 22, Frequency: 0.000004, Keep Probability: 1.000000
# Word: '3year', Count: 23, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'trumpet', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'fennel', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '20kg', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'reclaim', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'ghee', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'parameter', Count: 21, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'lara', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'laura', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'myjio', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'trimester', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'unify', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'mam', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'oj', Count: 20, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'captivity', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'oneonone', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'couriers', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'uti', Count: 16, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'semaphore', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'pax', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'silicone', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'undo', Count: 28, Frequency: 0.000005, Keep Probability: 1.000000
# Word: 'aurangabad', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'rubin', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'peptobismol', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'hashing', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'verticals', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'chiefs', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dramatic', Count: 24, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'envision', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nm', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'renounce', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'childs', Count: 49, Frequency: 0.000008, Keep Probability: 1.000000
# Word: 'sinx', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'pointe', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'mates', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'greg', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'tsai', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nairobi', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'modernday', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'pints', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'exhale', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'weeping', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'balancer', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'reversal', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'trembling', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'taster', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'diazepam', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'refreshing', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'cpg', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'squirrels', Count: 25, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'donates', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'preposition', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'inlaws', Count: 16, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'apa', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'rainforests', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'handcuffs', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'cordova', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'shelters', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'milia', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'coherent', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: '030', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'katie', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'fabrication', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'aftr', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'insignia', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'unaccounted', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'preorder', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'boygirl', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'qbasic', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'scarce', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'accessing', Count: 33, Frequency: 0.000005, Keep Probability: 1.000000
# Word: 'emergence', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: '1300d', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'cinese', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'biasing', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '178', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nicer', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'adhaar', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'animagus', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'blob', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'platos', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'pharmacists', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'sponge', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'changeorg', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'focuses', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: '1year', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'premedical', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'homesick', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'nafta', Count: 22, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'plating', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'protien', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'cherokee', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'squatting', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'en', Count: 21, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'classifications', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'shopkeeper', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'baar', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'withholding', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'abscess', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'slapped', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'vicepresident', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'outofstate', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'floyds', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nicmar', Count: 37, Frequency: 0.000006, Keep Probability: 1.000000
# Word: 'alzheimer', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '458', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'raleigh', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'keith', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'rabois', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'brio', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '462', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'incomes', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'careless', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'jutsu', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'proudest', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'b3', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'demolish', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'planing', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'dal', Count: 16, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'erwin', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'rommel', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'panjab', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'finishes', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'nikesh', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'questionsanswers', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'hippies', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'googlers', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'blessings', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '1938', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'eyelid', Count: 16, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'ekta', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'bruises', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'cmat', Count: 23, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'elasticsearch', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dries', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'broadly', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'savvy', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sixpack', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ta', Count: 19, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'burglary', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'editable', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'withhold', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'malamutehusky', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'proactiv', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'goblet', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'narmada', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sasikala', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'paraffin', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'stabbing', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'soetoro', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'entities', Count: 19, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'sunil', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'gavaskar', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '1070', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'barkha', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ravish', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'rebranding', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'indepth', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'devi', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'rukmini', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ferrets', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'wifegirlfriend', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'blackstone', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'wysiwyg', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'cx275s', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'oscillating', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'waving', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'subculture', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ivan', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'groovy', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'overwhelmingly', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'josephus', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'underpaid', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'remastered', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mosque', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'zappa', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'disowned', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'timely', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'maximus', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'tit', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'tat', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ringworm', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'whyhow', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'grit', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ewoks', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'emperors', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'bothers', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'pavement', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'egotistical', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'undesirable', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'detailing', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'i797', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'routers', Count: 27, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'netaji', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'pilgrims', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'awaken', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'cody', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dive', Count: 18, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'ntt', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'profanity', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'unimportant', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sunrise', Count: 18, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'culprit', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'harmless', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'capitals', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'angered', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'petite', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'psycho', Count: 20, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'prussia', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'tes', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'tacky', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'jurisdictions', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'colonel', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'prescribing', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'kaur', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'outing', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'idt', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'benifits', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'privatisation', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'parallels', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'shunned', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'topmost', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'layaway', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'roy', Count: 25, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'farc', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'salted', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'cid', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sensations', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'jackie', Count: 28, Frequency: 0.000005, Keep Probability: 1.000000
# Word: 'magna', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'sould', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'angled', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'duos', Count: 23, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'grenade', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'assessed', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'quasi', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'augustus', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'jo', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sama', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'overboard', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'instructors', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'parachutes', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'screenwriter', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'conglomerate', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'snooze', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'freddie', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'practicum', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'broader', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'demi', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'lovato', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'bleached', Count: 20, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'heartwarming', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'collegium', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'cheddar', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dsm', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'delusions', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'armature', Count: 16, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'paganism', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'methylphenidate', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'abundance', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'uploader', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ibpspo', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'magistrate', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'naam', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'conceptual', Count: 23, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'maroon', Count: 16, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'metamorphic', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'possessiveness', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'stale', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'abducted', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'extraterrestrials', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'zebras', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'cheetahs', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'calmer', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'polymath', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'cutter', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ketosis', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'hydraulics', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'listerine', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'carat', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '300k', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'trapezoid', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'haemoglobin', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'stunning', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'sociologists', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'enormous', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: '375', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'busiest', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'gigabytes', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'canberra', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ethnically', Count: 19, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'nursery', Count: 21, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'surgeries', Count: 19, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'upanishads', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'advocating', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '1978', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dekho', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'unused', Count: 24, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'matcha', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'rajdeep', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sardesai', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'hft', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'valdosta', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'ao', Count: 36, Frequency: 0.000006, Keep Probability: 1.000000
# Word: 'lowered', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: '4600', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'pouch', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'glad', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'assembling', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'innie', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'outie', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'kundli', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'altitudes', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'examiner', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'habeas', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'pottermore', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'xrays', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'umrah', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sonnet', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'eighteen', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ftii', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'clues', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'neutered', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'factually', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'physiotherapist', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'fleece', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'veterinarians', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'starring', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'praying', Count: 25, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'o1', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'incremental', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'disclosure', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'prog', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '10000000', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'enthusiast', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'ebt', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'serie', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'criticizing', Count: 16, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'blooded', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'deniers', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'flirts', Count: 21, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'operative', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'bscit', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dank', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mjolnir', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'alevel', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'discarded', Count: 15, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'mfc', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'telephonic', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'silently', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'designations', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'jntu', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'chainsaw', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sheryl', Count: 23, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'shallow', Count: 21, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'promiscuity', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'lalu', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'prasad', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ferdinand', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dnt', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nutmeg', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'kenny', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'characterizes', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'changer', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'hitachi', Count: 14, Frequency: 0.000002, Keep Probability: 1.000000
# Word: '143', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'bestmost', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'lexapro', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'resurgence', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '10092016', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'antonyms', Count: 17, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'acl', Count: 21, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'leisure', Count: 23, Frequency: 0.000004, Keep Probability: 1.000000
# Word: 'awhile', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mustafa', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'tenants', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '0000', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'submariner', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'annuity', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'kefir', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'submerged', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'neurolinguistic', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'raga', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'cents', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mutated', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'pitches', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'ef', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'memorizing', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'serviced', Count: 13, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'clothings', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nets', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'taoism', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'diplomas', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'utilizes', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'saraswati', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'yamuna', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'uncontrollable', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'r5', Count: 18, Frequency: 0.000003, Keep Probability: 1.000000
# Word: 'm330', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'chimney', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# ...
# Word: 'repent', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'thereby', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'radiate', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'incs', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'deplorable', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'indiape', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mfn', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'blaster', Count: 12, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'foodpanda', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'alienate', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '12mm', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mls', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'atlassian', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'px', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'eraser', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'incandescent', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'modinagar', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mathamath', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'autocomplete', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'hull', Count: 10, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'severance', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'downing', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'friendster', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'eagerpanda', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'deva', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'diogenes', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'milliliters', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mahmud', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'homozygous', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nr', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'jntuh', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'stag', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'inappropriately', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nostrils', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'meerkat', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'leyland', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'chaturthi', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'wherein', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'rsorder', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'gana', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'asexuality', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mccain', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'r2', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'chilling', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nashville', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'conceptually', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'copyrightfree', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'imgur', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'randomness', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'encouragement', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'spoof', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'chandlers', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'doped', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'multiplexer', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'embeded', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'pcmc', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ravioli', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'iraqis', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'knob', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'separatist', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'estimating', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'balkans', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '2bhk', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'foliated', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mana', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'spanishspeaking', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'jobscareers', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dvr', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '9066', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'alkyl', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'discos', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mlas', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'tans', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'a2as', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'homejoy', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'tunein', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'subprime', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'pomade', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'genomics', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'memoirs', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'chanakyas', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'scold', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'limbaugh', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'immaturity', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'प', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'rtl', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'shadowing', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'pcmb', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'inflammatory', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ட', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'க', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'த', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'topical', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'platelet', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'asi', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'malignant', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'serbian', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'eluga', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'weeaboo', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'rut', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'fortiguard', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'withdrawl', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mag', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'caleb', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'cmyk', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'daad', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'discriminatory', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'quidditch', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'silos', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'unqualified', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'invalidate', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'misery', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'tambora', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'awdhesh', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'tenors', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'phoebe', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'zhihu', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nootropic', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'judgments', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'catagory', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'durham', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'descending', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'fellows', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'globalism', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'accordance', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'benevolent', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'tefl', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'p9', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'rotis', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'meowing', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'gitam', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'epsilon', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'jacobs', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'writein', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'unofficially', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '⚡', Count: 11, Frequency: 0.000002, Keep Probability: 1.000000
# Word: 'substrates', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'lids', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'npm', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'lineage', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'shawn', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'crankshaft', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'bayern', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sqrt2', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'immersed', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'spat', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'syrians', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'soaring', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'quo', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'uninteresting', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'impacting', Count: 8, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'appreciates', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'pratap', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'escalator', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'princely', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'vigorous', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'oncology', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'redesigned', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '6500u', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'alipay', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'hyperventilation', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'hodor', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'finisher', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'communicated', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'boggart', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ballots', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sqrtc', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sqrtd', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'peaky', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'blinders', Count: 9, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'bloodline', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'mascots', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '27k', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'zakat', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'boyfriendhusband', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'grappling', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'metaphysical', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'authenticate', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'quack', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'distributorship', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'adolescent', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'delight', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'npci', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'paleontology', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'clustered', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'foxpro', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'ubisoft', Count: 7, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'unweighted', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '1750', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'pigments', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'gated', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dabi', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'stun', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '‬', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'golfers', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'volunteers', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'inserts', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'unsaved', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'duplicated', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'femoral', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'psbs', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'heterozygous', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'basanti', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '2k17', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'sommelier', Count: 6, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '∠', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'blizzards', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'nineteen', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'eaadhaar', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'dynamos', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: '512mb', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000
# Word: 'shankaracharya', Count: 5, Frequency: 0.000001, Keep Probability: 1.000000

# %%
negative_sampling_prob_dict = get_negative_sampling_prob(word_count_dict)
assert negative_sampling_prob_dict.keys() == negative_sampling_prob_dict.keys()
assert np.allclose(sum(negative_sampling_prob_dict.values()), 1)

# %% [markdown]
# Если все прошло успешно, функция ниже поможет вам с генерацией подвыборок (батчей).

# %%
def generate_batch_with_neg_samples(
    context_pairs,
    batch_size,
    keep_prob_array,
    word_to_index,
    num_negatives,
    negative_sampling_prob_array,
):
    batch = []
    neg_samples = []

    while len(batch) < batch_size:
        center, context = random.choice(context_pairs)
        if random.random() < keep_prob_array[center]:
            batch.append((center, context))
            neg_sample = np.random.choice(
                range(len(negative_sampling_prob_array)),
                size=num_negatives,
                p=negative_sampling_prob_array,
            )
            neg_samples.append(neg_sample)
    batch = np.array(batch)
    neg_samples = np.vstack(neg_samples)
    return batch, neg_samples

# %%
batch_size = 4
num_negatives = 15
batch, neg_samples = generate_batch_with_neg_samples(
    context_pairs,
    batch_size,
    keep_prob_array,
    word_to_index,
    num_negatives,
    negative_sampling_prob_array,
)

# %% [markdown]
# Наконец, время реализовать модель. Обращаем ваше внимание, использование линейных слоев (`nn.Linear`) далеко не всегда оправданно!
#
# Напомним, что в случае negative sampling решается задача максимизации следующего функционала:
#
# $$
# \mathcal{L} = \log \sigma({\mathbf{v}'_{w_O}}^\top \mathbf{v}_{w_I}) + \sum_{i=1}^{k} \mathbb{E}_{w_i \sim P_n(w)} \left[ \log \sigma({-\mathbf{v}'_{w_i}}^\top \mathbf{v}_{w_I}) \right],
# $$
#
# где:
# - $\mathbf{v}_{w_I}$ – вектор центрального слова $w_I$,
# - $\mathbf{v}'_{w_O}$ – вектор слова из контекста $w_O$,
# - $k$ – число negative samplesЮ,
# - $P_n(w)$ – распределение negative samples, заданное выше,
# - $\sigma$ – сигмоида.

# %%
class SkipGramModelWithNegSampling(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super().__init__()
        self.center_embeddings = None  # YOUR CODE HERE
        self.center_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.context_embeddings = None  # YOUR CODE HERE
        self.context_embeddings = nn.Embedding(vocab_size, embedding_dim)

    def forward(self, center_words, pos_context_words, neg_context_words):
        pos_scores = 0  # THIS IS A PLACEHOLDER
        emb_center = self.center_embeddings(center_words)  # (batch_size, embedding_dim)
        emb_pos = self.context_embeddings(pos_context_words)  # (batch_size, embedding_dim)
        pos_scores = torch.sigmoid(torch.sum(emb_center * emb_pos, dim=1))  # (batch_size)

        neg_scores = 0  # THIS IS A PLACEHOLDER
        emb_neg = self.context_embeddings(neg_context_words)  # (batch_size, num_negatives, embedding_dim)
        neg_scores = torch.sigmoid(torch.bmm(emb_neg, emb_center.unsqueeze(2)).squeeze(2))

        return pos_scores, neg_scores

# %%
device = torch.device("cpu")

# %%
vocab_size = len(word_to_index)
embedding_dim = 32
num_negatives = 15

model = SkipGramModelWithNegSampling(vocab_size, embedding_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.05)
lr_scheduler = ReduceLROnPlateau(optimizer, factor=0.5, patience=150)
criterion = nn.BCEWithLogitsLoss()

# %%
params_counter = 0
for weights in model.parameters():
    params_counter += weights.shape.numel()
assert params_counter == len(word_to_index) * embedding_dim * 2

# %%
def train_skipgram_with_neg_sampling(
    model,
    context_pairs,
    keep_prob_array,
    word_to_index,
    batch_size,
    num_negatives,
    negative_sampling_prob_array,
    steps,
    optimizer=optimizer,
    lr_scheduler=lr_scheduler,
    device=device,
):
    pos_labels = torch.ones(batch_size).to(device)
    neg_labels = torch.zeros(batch_size, num_negatives).to(device)
    loss_history = []
    for step in tqdma(range(steps)):
        batch, neg_samples = generate_batch_with_neg_samples(
            context_pairs,
            batch_size,
            keep_prob_array,
            word_to_index,
            num_negatives,
            negative_sampling_prob_array,
        )
        center_words = torch.tensor([pair[0] for pair in batch], dtype=torch.long).to(
            device
        )
        pos_context_words = torch.tensor(
            [pair[1] for pair in batch], dtype=torch.long
        ).to(device)
        neg_context_words = torch.tensor(neg_samples, dtype=torch.long).to(device)

        optimizer.zero_grad()
        pos_scores, neg_scores = model(
            center_words, pos_context_words, neg_context_words
        )

        loss_pos = criterion(pos_scores, pos_labels)
        loss_neg = criterion(neg_scores, neg_labels)

        loss = loss_pos + loss_neg
        loss.backward()
        optimizer.step()

        loss_history.append(loss.item())
        lr_scheduler.step(loss_history[-1])

        if step % 100 == 0:
            print(
                f"Step {step}, Loss: {np.mean(loss_history[-100:])}, learning rate: {lr_scheduler._last_lr}"
            )

# %%
steps = 2500
batch_size = 512
train_skipgram_with_neg_sampling(
    model,
    context_pairs,
    keep_prob_array,
    word_to_index,
    batch_size,
    num_negatives,
    negative_sampling_prob_array,
    steps,
)
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# Step 0, Loss: 1.4925978183746338, learning rate: [0.05]
# Step 100, Loss: 1.4884948682785035, learning rate: [0.05]
# Step 200, Loss: 1.4863491702079772, learning rate: [0.05]
# Step 300, Loss: 1.4823380053043365, learning rate: [0.05]
# Step 400, Loss: 1.4727938771247864, learning rate: [0.05]
# Step 500, Loss: 1.4595454573631286, learning rate: [0.05]
# Step 600, Loss: 1.437122449874878, learning rate: [0.05]
# Step 700, Loss: 1.4156735956668853, learning rate: [0.05]
# Step 800, Loss: 1.3967143177986145, learning rate: [0.05]
# Step 900, Loss: 1.37907559633255, learning rate: [0.05]
# Step 1000, Loss: 1.3669183766841888, learning rate: [0.05]
# Step 1100, Loss: 1.3579425382614136, learning rate: [0.05]
# Step 1200, Loss: 1.3526818716526032, learning rate: [0.05]
# Step 1300, Loss: 1.349886269569397, learning rate: [0.025]
# Step 1400, Loss: 1.344072506427765, learning rate: [0.025]
# Step 1500, Loss: 1.3415256762504577, learning rate: [0.025]
# Step 1600, Loss: 1.3411426591873168, learning rate: [0.025]
# Step 1700, Loss: 1.3383947110176087, learning rate: [0.025]
# Step 1800, Loss: 1.336842646598816, learning rate: [0.025]
# Step 1900, Loss: 1.33588348031044, learning rate: [0.025]
# Step 2000, Loss: 1.332235906124115, learning rate: [0.025]
# Step 2100, Loss: 1.333798794746399, learning rate: [0.025]
# Step 2200, Loss: 1.3322334218025207, learning rate: [0.0125]
# Step 2300, Loss: 1.3300014996528626, learning rate: [0.00625]
# Step 2400, Loss: 1.3311939215660096, learning rate: [0.00625]

# %% [markdown]
# Наконец, используйте полученную матрицу весов в качестве матрицы в векторными представлениями слов. Рекомендуем использовать для сдачи матрицу, которая отвечала за слова из контекста (т.е. декодера).

# %%
_model_parameters = model.parameters()
embedding_matrix_center = next(
    _model_parameters
).detach()  # Assuming that first matrix was for central word
embedding_matrix_context = next(
    _model_parameters
).detach()  # Assuming that second matrix was for context word

# %%
def get_word_vector(word, embedding_matrix, word_to_index=word_to_index):
    return embedding_matrix[word_to_index[word]]

# %% [markdown]
# Простые проверки:

# %%
similarity_1 = F.cosine_similarity(
    get_word_vector("iphone", embedding_matrix_context)[None, :],
    get_word_vector("apple", embedding_matrix_context)[None, :],
)
similarity_2 = F.cosine_similarity(
    get_word_vector("iphone", embedding_matrix_context)[None, :],
    get_word_vector("dell", embedding_matrix_context)[None, :],
)
assert similarity_1 > similarity_2
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-44-16bed20f46b1> in <cell line: 9>()
#       7     get_word_vector("dell", embedding_matrix_context)[None, :],
#       8 )
# ----> 9 assert similarity_1 > similarity_2
#
# AssertionError:

# %%
print("Cosine similarity between 'iphone' and 'apple':", similarity_1.item())
print("Cosine similarity between 'iphone' and 'dell':", similarity_2.item())
# Out:
# Cosine similarity between 'iphone' and 'apple': 0.16942080855369568
# Cosine similarity between 'iphone' and 'dell': 0.31686556339263916

# %%
similarity_1 = F.cosine_similarity(
    get_word_vector("windows", embedding_matrix_context)[None, :],
    get_word_vector("laptop", embedding_matrix_context)[None, :],
)
similarity_2 = F.cosine_similarity(
    get_word_vector("windows", embedding_matrix_context)[None, :],
    get_word_vector("macbook", embedding_matrix_context)[None, :],
)
assert similarity_1 > similarity_2

# %% [markdown]
# Наконец, взглянем на ближайшие по косинусной мере слова. Функция реализована ниже.

# %%
def find_nearest(word, embedding_matrix, word_to_index=word_to_index, k=10):
    word_vector = get_word_vector(word, embedding_matrix)[None, :]
    dists = F.cosine_similarity(embedding_matrix, word_vector)
    index_sorted = torch.argsort(dists)
    top_k = index_sorted[-k:]
    return [(index_to_word[x], dists[x].item()) for x in top_k.numpy()]

# %%
find_nearest("python", embedding_matrix_context, k=10)
# Out:
# [('selfies', 0.7680594325065613),
#  ('yoga', 0.7739742994308472),
#  ('selfawareness', 0.7747997045516968),
#  ('responses', 0.777854859828949),
#  ('manufactured', 0.7804319858551025),
#  ('stable', 0.7872733473777771),
#  ('prozac', 0.7930295467376709),
#  ('reached', 0.8169853687286377),
#  ('verbally', 0.818450391292572),
#  ('python', 0.9999999403953552)]

# %% [markdown]
# Также вы можете визуально проверить, как представлены в латентном пространстве часто встречающиеся слова.

# %%
top_k = 5000
_top_words = sorted([x for x in word_count_dict.items()], key=lambda x: x[1])[
    -top_k - 100 : -100
]  # ignoring 100 most frequent words
top_words = [x[0] for x in _top_words]
del _top_words

# %%
word_embeddings = torch.cat(
    [embedding_matrix_context[word_to_index[x]][None, :] for x in top_words], dim=0
).numpy()

# %%
import bokeh.models as bm
import bokeh.plotting as pl
from bokeh.io import output_notebook

output_notebook()


def draw_vectors(
    x,
    y,
    radius=10,
    alpha=0.25,
    color="blue",
    width=600,
    height=400,
    show=True,
    **kwargs,
):
    """draws an interactive plot for data points with auxilirary info on hover"""
    if isinstance(color, str):
        color = [color] * len(x)
    data_source = bm.ColumnDataSource({"x": x, "y": y, "color": color, **kwargs})

    fig = pl.figure(active_scroll="wheel_zoom", width=width, height=height)
    fig.scatter("x", "y", size=radius, color="color", alpha=alpha, source=data_source)

    fig.add_tools(bm.HoverTool(tooltips=[(key, "@" + key) for key in kwargs.keys()]))
    if show:
        pl.show(fig)
    return fig

# %%
embedding = umap.UMAP(n_neighbors=5).fit_transform(word_embeddings)

# %%
draw_vectors(embedding[:, 0], embedding[:, 1], token=top_words)
# Out:
#   <div id="d84073ad-8f4d-4278-b4f7-9b1b6abe0645" data-root-id="p1004" style="display: contents;"></div>
# figure(id='p1004', ...)

# %% [markdown]
# Для сдачи задания необходимо загрузить функции `subsample_frequent_words` и `get_negative_sampling_prob`, а также сгенерировать файл для посылки ниже и приложить в соответствующую задачу. Успехов!

# %%
# do not change the code in the block below
# __________start of block__________
import os
import json

assert os.path.exists(
    "words_subset.txt"
), "Please, download `words_subset.txt` and place it in the working directory"

with open("words_subset.txt") as iofile:
    selected_words = iofile.read().split("\n")


def get_matrix_for_selected_words(selected_words, embedding_matrix, word_to_index):
    word_vectors = []
    for word in selected_words:
        index = word_to_index.get(word, None)
        vector = [0.0] * embedding_matrix.shape[1]
        if index is not None:
            vector = embedding_matrix[index].numpy().tolist()
        word_vectors.append(vector)
    return word_vectors


word_vectors = get_matrix_for_selected_words(
    selected_words, embedding_matrix_context, word_to_index
)

with open("submission_dict.json", "w") as iofile:
    json.dump(word_vectors, iofile)
print("File saved to `submission_dict.json`")
# __________end of block__________
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-53-05a6ffec4d9b> in <cell line: 6>()
#       4 import json
#       5
# ----> 6 assert os.path.exists(
#       7     "words_subset.txt"
#       8 ), "Please, download `words_subset.txt` and place it in the working directory"
#
# AssertionError: Please, download `words_subset.txt` and place it in the working directory
